# %%
# This is a single-line comment
print("Hello, Python!")

"""This is a
multi-line comment / docstring."""
# Out:
# Hello, Python!
# 'This is a\nmulti-line comment / docstring.'

# %%
name = "Aarav"
age = 18
height = 5.8
is_student = True

print(name, age, height, is_student)
print(type(name))
print(type(age))
# Out:
# Aarav 18 5.8 True
# <class 'str'>
# <class 'int'>

# %%
course = "AI Bootcamp"

print(course)
print(course[0])           # First character
print(course[-1])          # Last character
print(course[0:2])         # Slicing
print(course.lower())
print(course.upper())
print(course.replace("AI", "Python"))
print(len(course))
# Out:
# AI Bootcamp
# A
# p
# AI
# ai bootcamp
# AI BOOTCAMP
# Python Bootcamp
# 11

# %%
name = "Ananya"
score = 92

print("Student:", name, "Score:", score)
print("Student: {} | Score: {}".format(name, score))
print(f"Student: {name} | Score: {score}")
# Out:
# Student: Ananya Score: 92
# Student: Ananya | Score: 92
# Student: Ananya | Score: 92

# %%
number_as_text = "25"
number = int(number_as_text)
price = float("99.50")
age_as_text = str(18)

print(number + 5)
print(price)
print("Age: " + age_as_text)
# Out:
# 30
# 99.5
# Age: 18

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print(f"Hello {name}. Next year, you will be {age + 1}.")
# Out:
# Hello Abhi. Next year, you will be 13.

# %%
a = 10
b = 3

print(a + b)   # Addition
print(a - b)   # Subtraction
print(a * b)   # Multiplication
print(a / b)   # Division
print(a // b)  # Floor division
print(a % b)   # Remainder
print(a ** b)  # Power
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
age = 18
has_id_card = True

print(age >= 18)                 # Comparison
print(age >= 18 and has_id_card) # and
print(age < 18 or has_id_card)   # or
print(not has_id_card)           # not
# Out:
# True
# True
# True
# False

# %%
count = 10
count += 5
count *= 2
print(count)

subjects = ["Python", "Maths", "AI"]
print("Python" in subjects)
print("Physics" not in subjects)
# Out:
# 30
# True
# True

# %%
marks = 78

if marks >= 90:
    grade = "A+"
elif marks >= 75:
    grade = "A"
elif marks >= 60:
    grade = "B"
else:
    grade = "C"

print("Grade:", grade)
# Out:
# Grade: A

# %%
age = 20
has_ticket = True

if age >= 18:
    if has_ticket:
        print("You may enter.")
    else:
        print("Please buy a ticket.")
else:
    print("You must be at least 18 years old.")
# Out:
# You may enter.

# %%
for number in range(1, 6):
    print(number)

for subject in ["Python", "Data Science", "AI"]:
    print(subject)
# Out:
# 1
# 2
# 3
# 4
# 5
# Python
# Data Science
# AI

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for number in range(1, 11):
    if number == 3:
        continue  # Skip 3
    if number == 8:
        break     # Stop at 8
    print(number)

if True:
    pass  # Placeholder for code to be written later
# Out:
# 1
# 2
# 4
# 5
# 6
# 7

# %%
skills = ["Python", "Git", "Pandas"]

skills.append("NumPy")
skills.insert(1, "Data Preprocessing")
skills.remove("Git")
first_skill = skills.pop(0)

print(skills)
print(first_skill)
print(len(skills))
# Out:
# ['Data Preprocessing', 'Pandas', 'NumPy']
# Python
# 3

# %%
numbers = [10, 20, 30, 40, 50]

print(numbers[0])      # First item
print(numbers[-1])     # Last item
print(numbers[1:4])    # Items at indexes 1, 2, 3
print(numbers[::-1])   # Reversed list
# Out:
# 10
# 50
# [20, 30, 40]
# [50, 40, 30, 20, 10]

# %%
numbers = [4, 1, 3, 1, 2]

numbers.sort()
print(numbers)

numbers.reverse()
print(numbers)

print(numbers.count(1))
new_numbers = numbers.copy()
print(new_numbers)
# Out:
# [1, 1, 2, 3, 4]
# [4, 3, 2, 1, 1]
# 2
# [4, 3, 2, 1, 1]

# %%
squares = [number ** 2 for number in range(1, 6)]
even_numbers = [number for number in range(1, 11) if number % 2 == 0]

print(squares)
print(even_numbers)
# Out:
# [1, 4, 9, 16, 25]
# [2, 4, 6, 8, 10]

# %%
coordinates = (28.7041, 77.1025)
student = ("Aarav", 18, "CSE")

print(coordinates[0])
print(student)

# Tuples are immutable: coordinates[0] = 0 would cause an error
# Out:
# 28.7041
# ('Aarav', 18, 'CSE')
